# %% [markdown]
# <a href="https://colab.research.google.com/github/LingliHelen/faang-event-study/blob/main/faang_event_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Impact of Macroeconomic Announcements on FAANG Stocks

# %%
# libraries

import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# plot settings
sns.set(style='whitegrid')

# download stock data

stock_tickers = ['AAPL', 'MSFT', 'META']

market_ticker = 'SPY'

all_tickers = stock_tickers + [market_ticker]

# start and end date for analysis
start = '2022-08-01'

end = '2025-08-01'

# download adjusted close prices (auto-adjust=True is used to avoid effect on dividends or stock split)

raw_data = yf.download(all_tickers, start=start, end=end, auto_adjust=True)

prices = raw_data['Close']

returns = prices.pct_change().dropna()

# check first 5 rows to see if data is downloaded correctly

print(prices.head())

# calculate daily simple returns (use simple return method to see the percentage of  day to day changes, and drop NaN)

market_return = returns[market_ticker]

abnormal_returns = returns[stock_tickers].sub(market_return, axis=0)

# identify and define the major market event that has a significant impact on the market

event_identify = {
    'Fed Rate Hike #1': '2022-09-21',
    'Inflation Release': '2023-01-12',
    'Fed Rate Hike #2': '2023-03-22',
    'Tech Earnings Report': '2023-07-25',
    'Fed Rate Hike #3': '2023-09-20'
}

# convert events occurrence to pandas datetime, to make format the same

event_dates = pd.to_datetime(list(event_identify.values()))

# plot price chart with events

plt.figure(figsize=(14, 8))
for t in stock_tickers:
    plt.plot(prices.index, prices[t], label=t)

# add event markers, make it easy to see in the plot and know more about fluctuation before and after the event for the three stocks that I choose

for label, d in event_identify.items():
    d = pd.to_datetime(d)
    plt.axvline(d, linestyle='--', color='gray', alpha=0.6)
    plt.text(d, plt.ylim()[1]*0.95, label, rotation=90, ha='right', fontsize=9)

plt.title('FAANG Stock Prices with Major Market Events')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price (USD)')
plt.legend()
plt.tight_layout()
plt.show()

# cumulative returns around events, make the window period to 5 to see what fluctuation around the period

event_period = 5
event_returns = {}

for name, date_str in event_identify.items():
    event_day = pd.to_datetime(date_str)

    # create a 15 calendar-based day window around that period

    calendar_buffer = 15
    buffer_start = event_day - pd.Timedelta(days=calendar_buffer)
    buffer_end = event_day + pd.Timedelta(days=calendar_buffer)

    # select rows within the calendar buffer range
    calendar_window = abnormal_returns.loc[buffer_start:buffer_end]

    window_data = calendar_window.copy()

    window_data = window_data.reset_index()

    window_data['Days From Event'] = (window_data['Date'] - event_day).dt.days

    # make a copy to avoid modifying the original data, keep original data stay

    window_data = calendar_window.copy()

    # reset the index so the Date becomes a column

    window_data = window_data.reset_index()

    # calculate days from the event

    window_data['Days From Event'] = (window_data['Date'] - event_day).dt.days


    # define the condition for rows that are within the event window range
    condition = (
       (window_data['Days From Event'] >= -event_period) &  # Condition for days before the event
        (window_data['Days From Event'] <= event_period)      # Condition for days after the event
    )

    filtered_data = window_data[condition]
    filtered_data = filtered_data.set_index('Days From Event')

    # apply the condition to filter the DataFrame

    filtered_data = window_data[condition]

    # set 'Days From Event' as the new index for easier access

    filtered_data = filtered_data.set_index('Days From Event')


    # select only the return columns for the chosen 3 stock tickers

    daily_returns = filtered_data[stock_tickers]

    # convert daily rsimple eturns to growth factors (1 + return)

    growth_factors = 1 + daily_returns

    # calculate the cumulative product over time

    cumulative_growth = growth_factors.cumprod()

    # convert back to cumulative return by subtracting 1

    cumret = cumulative_growth - 1

    # save the result in the event_returns dictionary

    event_returns[name] = cumret

plt.figure(figsize=(8,4))

cr = event_returns['Fed Rate Hike #1']

for t in stock_tickers:
    plt.plot(cr.index, cr[t], label=t)

# sample visualization for README
plt.axvline(0, linestyle='--', color='black')
plt.title('Cumulative Abnormal Returns: Fed Rate Hike #1')
plt.xlabel('Days From Event')
plt.ylabel('Cumulative Return')
plt.legend()

plt.tight_layout()
plt.savefig("event_example.png", dpi=300)
plt.show()

# plot cumulative return around each event

plt.figure(figsize=(14, 10))

for idx, (event_name, cr) in enumerate(event_returns.items(), 1):
    plt.subplot(len(event_returns), 1, idx)
    for t in stock_tickers:
        plt.plot(cr.index, cr[t], label=t)
    plt.axvline(0, color='black', linestyle='--')
    plt.title(f'Cumulative Returns: {event_name}')
    plt.xlabel('Days From Event')
    plt.ylabel('Cumulative Return')
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.savefig("faang_market_events.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# [*********************100%***********************]  4 of 4 completed
# Ticker            AAPL        META        MSFT         SPY
# Date
# 2022-08-01  158.477539  158.820587  269.566498  391.446106
# 2022-08-02  157.005646  159.078796  266.473358  388.863525
# 2022-08-03  163.010788  167.629059  273.891052  394.952942
# 2022-08-04  162.696762  169.386780  275.035156  394.686157
# 2022-08-05  162.470810  165.950775  274.317657  394.019012
